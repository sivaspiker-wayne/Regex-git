# %% [markdown]
# ##Regex (Regular Expression)
# - it is a special sequence of characters that defines a search pattern.

# %% [markdown]
# Pattern Matching → Find text that follows a rule (like email addresses, phone numbers).
#
# Validation → Check if input matches a format (like PIN codes, passwords, dates).
#
# Text Extraction → Extract useful info (like extracting all hashtags from tweets).
#
# Text Cleaning → Remove unwanted characters, symbols, or whitespace.

# %%
print(r"this is my channel name\nrah_data")
# Out:
# this is my channel name\nrah_data

# %%
import re as r

# %%
help(r)
# Out:
# Help on package re:
#
# NAME
#     re - Support for regular expressions (RE).
#
# MODULE REFERENCE
#     https://docs.python.org/3.12/library/re.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     This module provides regular expression matching operations similar to
#     those found in Perl.  It supports both 8-bit and Unicode strings; both
#     the pattern and the strings being processed can contain null bytes and
#     characters outside the US ASCII range.
#
#     Regular expressions can contain both special and ordinary characters.
#     Most ordinary characters, like "A", "a", or "0", are the simplest
#     regular expressions; they simply match themselves.  You can
# ...

# %% [markdown]
# . – Any character
#
# \n – Newline character
#
# \t – Tab character
#
# \s– Any whitespace character (including \t, \n and a few others)
#
# \S – Any non-whitespace character
#
# \w– Any word character (Uppercase and lowercase Latin alphabet, numbers 0-9, and _)
#
# \W– Any non-word character (the inverse of the \w token)
#
# \b– Word boundary: The boundaries between \w and \W, but matches in-between characters
#
# \B– Non-word boundary: The inverse of \b
#
# ^ – The start of a line
#
# $ – The end of a line
#
# \– The literal character “\”

# %%
text1[0:5]
# Out:
# 'Match'

# %%
text1  = 'Match a regular expression string pattern to the beginning of a string.'
r.match("Match",text1)
# Out:
# <re.Match object; span=(0, 5), match='Match'>

# %%
text = """ Scan through string looking for a match, and
return a corresponding match object instance.
THE CALCULATE Function is used to perform the DATEDIFF calculation within
the context of the current filter context.
The DATEDIFF function calculates the difference in
days between the "Today_date" and "Order Date" columns."""
r.search(r"the",text,flags = r.IGNORECASE)
# Out:
# <re.Match object; span=(135, 138), match='the'>

# %%
res1 = r.search("The",text,flags = r.IGNORECASE)
print(res1)
# Out:
# <re.Match object; span=(93, 96), match='THE'>

# %%
r.findall("the",text,flags = r.IGNORECASE)
# Out:
# ['THE', 'the', 'the', 'the', 'The', 'the', 'the']

# %%
help(r)
# Out:
# Help on package re:
#
# NAME
#     re - Support for regular expressions (RE).
#
# MODULE REFERENCE
#     https://docs.python.org/3.11/library/re.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     This module provides regular expression matching operations similar to
#     those found in Perl.  It supports both 8-bit and Unicode strings; both
#     the pattern and the strings being processed can contain null bytes and
#     characters outside the US ASCII range.
#
#     Regular expressions can contain both special and ordinary characters.
#     Most ordinary characters, like "A", "a", or "0", are the simplest
#     regular expressions; they simply match themselves.  You can
# ...

# %%
data = """ Subject Line (90 characters): "Meeting reminder: Sales Strategy Discussion @ 2 PM"
Social Media Post (140 characters): "Feeling grateful for another sunny day! ☀️ What are you thankful for today?"
SMS Notification (130 characters): "Your order #12345 has shipped! Track it here: [link]" (146 with bracketed link)
Website Banner (100 characters): 77089283356"Free Shipping on All Orders Over $50! Shop Now!" 123-456-7890
News Headline (120 characters): "Local Artist Wins National Award for Stunning Sculpture"
Short Product Description (140 characters): "Lightweight, wireless headphones with superior sound quality and long battery life. Perfect for workouts!"
Quote (130 characters): 009-3241-4241 7010036103The only person you are destined to become is the person you decide to be. - Ralph Waldo Emerson" (148 with quotation marks)
Event Invitation 9626626081 (140 characters): "Join us for a fun night of board games! Food and drinks provided. RSVP by [date]."
Survey Question (120 characters): "What's your favorite feature of our new mobile app? 098-876-6543 Let us know in the comments!"
Blog Post Title (90 characters): "5 Simple Tips to Declutter Your Home and Organize Your Life"
"""

# %%
r.findall(r'\d{10,11}|\d{3,4}-\d{3,4}-\d{3,4}',data)
# Out:
# ['77089283356',
#  '123-456-7890',
#  '009-3241-4241',
#  '7010036103',
#  '9626626081',
#  '098-876-6543']

# %%
r.findall(r"\b[a-d]\w+\b",data,r.IGNORECASE)
# Out:
# ['characters',
#  'Discussion',
#  'characters',
#  'another',
#  'day',
#  'are',
#  'characters',
#  'bracketed',
#  'Banner',
#  'characters',
#  'All',
#  'characters',
#  'Artist',
#  'Award',
#  'Description',
#  'characters',
#  'and',
#  'battery',
#  'characters',
#  'are',
#  'destined',
#  'become',
#  'decide',
#  'be',
#  'characters',
#  'board',
#  'and',
#  'drinks',
#  'by',
#  'date',
#  'characters',
#  'app',
#  'comments',
#  'Blog',
#  'characters',
#  'Declutter',
#  'and']

# %%
r.findall(r"\b[a-zA-z]+\b",data)
# Out:
# ['Subject',
#  'Line',
#  'characters',
#  'Meeting',
#  'reminder',
#  'Sales',
#  'Strategy',
#  'Discussion',
#  'PM',
#  'Social',
#  'Media',
#  'Post',
#  'characters',
#  'Feeling',
#  'grateful',
#  'for',
#  'another',
#  'sunny',
#  'day',
#  'What',
#  'are',
#  'you',
#  'thankful',
#  'for',
#  'today',
#  'SMS',
#  'Notification',
#  'characters',
#  'Your',
#  'order',
#  'has',
#  'shipped',
#  'Track',
#  'it',
#  'here',
#  'link',
#  'with',
#  'bracketed',
#  'link',
#  'Website',
#  'Banner',
#  'characters',
#  'Free',
#  'Shipping',
#  'on',
#  'All',
#  'Orders',
#  'Over',
#  'Shop',
#  'Now',
#  'News',
#  'Headline',
#  'characters',
#  'Local',
#  'Artist',
#  'Wins',
#  'National',
#  'Award',
#  'for',
#  'Stunning',
#  'Sculpture',
#  'Short',
#  'Product',
#  'Description',
#  'characters',
#  'Lightweight',
#  'wireless',
#  'headphones',
#  'with',
#  'superior',
#  'sound',
#  'quality',
#  'and',
#  'long',
#  'battery',
#  'life',
#  'Perfect',
# ...

# %%
r.findall(r"\b\w{5}+\b",data)
# Out:
# ['Sales',
#  'Media',
#  'sunny',
#  'today',
#  'order',
#  '12345',
#  'Track',
#  'Local',
#  'Award',
#  'Short',
#  'sound',
#  'Quote',
#  'Ralph',
#  'Waldo',
#  'marks',
#  'Event',
#  'night',
#  'board',
#  'games',
#  'Title']

# %%
r.fullmatch(r"(?=.[a-z])",data)

# %%
r.findall(r"[fF]\w+",data)
# Out:
# ['Feeling',
#  'ful',
#  'for',
#  'ful',
#  'for',
#  'fication',
#  'Free',
#  'for',
#  'fe',
#  'fect',
#  'for',
#  'for',
#  'fun',
#  'Food',
#  'favorite',
#  'feature',
#  'fe']

# %%
r.findall(r"\w+",data)
# Out:
# ['Subject',
#  'Line',
#  '90',
#  'characters',
#  'Meeting',
#  'reminder',
#  'Sales',
#  'Strategy',
#  'Discussion',
#  '2',
#  'PM',
#  'Social',
#  'Media',
#  'Post',
#  '140',
#  'characters',
#  'Feeling',
#  'grateful',
#  'for',
#  'another',
#  'sunny',
#  'day',
#  'What',
#  'are',
#  'you',
#  'thankful',
#  'for',
#  'today',
#  'SMS',
#  'Notification',
#  '130',
#  'characters',
#  'Your',
#  'order',
#  '12345',
#  'has',
#  'shipped',
#  'Track',
#  'it',
#  'here',
#  'link',
#  '146',
#  'with',
#  'bracketed',
#  'link',
#  'Website',
#  'Banner',
#  '100',
#  'characters',
#  '7708928335',
#  'Free',
#  'Shipping',
#  'on',
#  'All',
#  'Orders',
#  'Over',
#  '50',
#  'Shop',
#  'Now',
#  '123',
#  '456',
#  '7890',
#  'News',
#  'Headline',
#  '120',
#  'characters',
#  'Local',
#  'Artist',
#  'Wins',
#  'National',
#  'Award',
#  'for',
#  'Stunning',
#  'Sculpture',
#  'Short',
#  'Product',
#  'Description',
#  '140',
#  'characters',
#  'Lightweight',
# ...

# %%
r.findall(r"\b[fF]\w+",data)
# Out:
# ['Feeling',
#  'for',
#  'for',
#  'Free',
#  'for',
#  'for',
#  'for',
#  'fun',
#  'Food',
#  'favorite',
#  'feature']

# %%
data2 = """
I ordered 2 pizzas (one with pepperoni  and another with extra cheese) for dinner at 7:00 PM.
 They should be delivered to my doorstep at 123 Main St. You can track the order status here [invalid URL removed].
 My phone number is (555) 555-5555 if you need to reach me.
According to a recent study, 8 out of 10 doctors recommend getting at least 7 hours of sleep each night.
 To learn more about healthy sleep habits, visit the National Sleep Foundation
 website: https://www.sleepfoundation.org/.
The deadline to register for the upcoming coding competition is Friday, June 21st at 5:00 PM PST.
Don't miss your chance to win the grand prize of $10,000! Find all the details and registration information
 on the competition website: https://www.hackerrank.com/contests.
On a successful search, we can use match.group(1) to get the match
value of a ragu@hotmail.com. first group and match.group(2) to get the match value of a second group.
Now let’s see how to use these two patterns to search any six-letter word and
two consecutive digits inside the target string
. abc@gmail.com,ravi1234@gmail.com,
gayu@idfcfirstbank.com,
suresh@yahoo.com, Today's weather forecast predicts a high of
78 degrees Fahrenheit and a low of 52 degrees Fahrenheit, with a 30% chance of rain in the afternoon. Remember to bring an umbrella if you're heading out!
Congratulations! You've won a free weekend getaway to a
luxurious beach resort!
 To claim your prize, call us at 1-800-TRAVEL-FUN (1-800-872-8357)
 and mention code "BEACH123". Be sure to book your trip by July 1st for availability.
"""
print(data2)
# Out:
# I ordered 2 pizzas (one with pepperoni  and another with extra cheese) for dinner at 7:00 PM.
#  They should be delivered to my doorstep at 123 Main St. You can track the order status here [invalid URL removed].
#  My phone number is (555) 555-5555 if you need to reach me.
# According to a recent study, 8 out of 10 doctors recommend getting at least 7 hours of sleep each night.
#  To learn more about healthy sleep habits, visit the National Sleep Foundation
#  website: https://www.sleepfoundation.org/.
# The deadline to register for the upcoming coding competition is Friday, June 21st at 5:00 PM PST.
# Don't miss your chance to win the grand prize of $10,000! Find all the details and registration information
#  on the competition website: https://www.hackerrank.com/contests.
# On a successful search, we can use match.group(1) to get the match
# value of a ragu@hotmail.com. first group and match.group(2) to get the match value of a second group.
# ...

# %%
r.findall(r"\w+",data2)
# Out:
# ['I',
#  'ordered',
#  '2',
#  'pizzas',
#  'one',
#  'with',
#  'pepperoni',
#  'and',
#  'another',
#  'with',
#  'extra',
#  'cheese',
#  'for',
#  'dinner',
#  'at',
#  '7',
#  '00',
#  'PM',
#  'They',
#  'should',
#  'be',
#  'delivered',
#  'to',
#  'my',
#  'doorstep',
#  'at',
#  '123',
#  'Main',
#  'St',
#  'You',
#  'can',
#  'track',
#  'the',
#  'order',
#  'status',
#  'here',
#  'invalid',
#  'URL',
#  'removed',
#  'My',
#  'phone',
#  'number',
#  'is',
#  '555',
#  '555',
#  '5555',
#  'if',
#  'you',
#  'need',
#  'to',
#  'reach',
#  'me',
#  'According',
#  'to',
#  'a',
#  'recent',
#  'study',
#  '8',
#  'out',
#  'of',
#  '10',
#  'doctors',
#  'recommend',
#  'getting',
#  'at',
#  'least',
#  '7',
#  'hours',
#  'of',
#  'sleep',
#  'each',
#  'night',
#  'To',
#  'learn',
#  'more',
#  'about',
#  'healthy',
#  'sleep',
#  'habits',
#  'visit',
#  'the',
#  'National',
#  'Sleep',
#  'Foundation',
#  'website',
#  'https',
#  'www',
#  'sleepfoundation',
# ...

# %%
pat = r"https://[^\s]+|\w+@\w+.\w+"
r.findall(pat,data)
# Out:
# []

# %%
import re
n = input("Enter the mail Id")
m = re.finditer(r'@\w+.\w+',n)
for i in m:
    y = i.start()
if n[y+1:] == "gmail.com":
    print("Its gmail Account")
elif n[y+1:] == "yahoo.com":
    print("Its yahoo.com")
elif n[y+1:] == "github.com":
    print("Its Github Account")
else:
    print("Mail id is invalid")
# Out:
# Enter the mail Idsdfghjk354@gmail.com
# Its gmail Account

# %%
text = """THE CALCULATE function is used to perform the DATEDIFF calculation within
 the context of the current filter context.
The DATEDIFF function calculates the difference in
days between the "Today_date" and "Order Date" columns."""
res = re.search("the",text)
print(res)
print(res.start())
print(res.end())
# Out:
# <re.Match object; span=(42, 45), match='the'>
# 42
# 45

# %%
text = "mothesh2000@gmail.com"
m = re.finditer(r'@\w+.\w+',text)
for i in m:
    print(i.start())
# Out:
# 11

# %%
text3 = "Match a regular expression pattern to the beginning of a string"
r.split(" ",text3)
# Out:
# ['Match',
#  'a',
#  'regular',
#  'expression',
#  'pattern',
#  'to',
#  'the',
#  'beginning',
#  'of',
#  'a',
#  'string']

# %%
text3 = "Match a regular expression pattern to the beginning of a string"
r.split(" ",text3,maxsplit = 2)
# Out:
# ['Match', 'a', 'regular expression pattern to the beginning of a string']

# %%
text3 = "Match a regular expression pattern to the beginning of a string"
r.split("n",text3)
# Out:
# ['Match a regular expressio',
#  ' patter',
#  ' to the begi',
#  '',
#  'i',
#  'g of a stri',
#  'g']

# %%
import re as r
data = """This module exports the following functions:
        match     Match a regular expression pattern to the beginning of a String.
        fullmatch Match a regular expression pattern to all of a strinGs.
        search    Search a strings for the presence of a pattern.
        sub       Substitute occurrences of a pattern found in a strIng.
        subn      Same as sub, but also return the number of substitutions made.
        split     Split a string by the occurrences of a pattern.
        findall   Find all occurrences of a pattern in a string.
        finditer  Return an iterator yielding a Match object for each match.
        compile   Compile a pattern into a Pattern object.
        purge     Clear the regular expression cache.
        escape    Backslash all non-alphanumerics in a strings.
"""
r.findall(r"\b[a-c]\w{3,4}\b",data,flags = r.IGNORECASE)
# Out:
# ['also', 'Clear', 'cache']

# %%
r.findall(r"strings?",data,r.IGNORECASE)
# Out:
# ['String', 'strinGs', 'strings', 'strIng', 'string', 'string', 'strings']

# %%
res = r.split(r"\b\w{4}\b",data)
res
# Out:
# ['',
#  ' module exports the following functions:\n        match     Match a regular expression pattern to the beginning of a String.\n        fullmatch Match a regular expression pattern to all of a strinG.\n        search    Search a string for the presence of a pattern.\n        sub       Substitute occurrences of a pattern found in a strIng.\n        ',
#  '      ',
#  ' as sub, but ',
#  ' return the number of substitutions ',
#  '.\n        split     Split a string by the occurrences of a pattern.\n        findall   ',
#  ' all occurrences of a pattern in a string.\n        finditer  Return an iterator yielding a Match object for ',
#  ' match.\n        compile   Compile a pattern ',
#  ' a Pattern object.\n        purge     Clear the regular expression cache.\n        escape    Backslash all non-alphanumerics in a string.\n']

# %% [markdown]
# SUB()
#
# sub()--> sub means substitution , or replacement
#
#       re.sub(pattern,replaceword,string)

# %%
data
# Out:
# 'This module exports the following functions:\n        match     Match a regular expression pattern to the beginning of a String.\n        fullmatch Match a regular expression pattern to all of a strinGs.\n        search    Search a strings for the presence of a pattern.\n        sub       Substitute occurrences of a pattern found in a strIng.\n        subn      Same as sub, but also return the number of substitutions made.\n        split     Split a string by the occurrences of a pattern.\n        findall   Find all occurrences of a pattern in a string.\n        finditer  Return an iterator yielding a Match object for each match.\n        compile   Compile a pattern into a Pattern object.\n        purge     Clear the regular expression cache.\n        escape    Backslash all non-alphanumerics in a strings.\n'

# %%
r.subn("string","STR",data,flags = r.IGNORECASE)
# Out:
# ('This module exports the following functions:\n        match     Match a regular expression pattern to the beginning of a STR.\n        fullmatch Match a regular expression pattern to all of a STRs.\n        search    Search a STRs for the presence of a pattern.\n        sub       Substitute occurrences of a pattern found in a STR.\n        subn      Same as sub, but also return the number of substitutions made.\n        split     Split a STR by the occurrences of a pattern.\n        findall   Find all occurrences of a pattern in a STR.\n        finditer  Return an iterator yielding a Match object for each match.\n        compile   Compile a pattern into a Pattern object.\n        purge     Clear the regular expression cache.\n        escape    Backslash all non-alphanumerics in a STRs.\n',
#  7)

# %%
name = r.compile('string',flags=r.IGNORECASE)
name
# Out:
# re.compile(r'string', re.IGNORECASE|re.UNICODE)

# %%
name.findall(data)
# Out:
# ['String', 'strinG', 'string', 'strIng', 'string', 'string', 'string']

# %%
name.findall(data2)
# Out:
# ['string', 'string', 'string']

# %%
name.findall(data3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-110799935.py in <cell line: 0>()
# ----> 1 name.findall(data3)
#
# NameError: name 'data3' is not defined

# %%
data2 = """A  ASCII       For string patterns, make \w, \W, \b, \B, \d, \D
                       match the corresponding ASCII character categories
                       (rather than the whole Unicode categories, which is the
                       default).
                       For bytes patterns, this flag is the only available
                       behaviour and needn't be specified.
        I  IGNORECASE  Perform case-insensitive matching.
        L  LOCALE      Make \w, \W, \b, \B, dependent on the current locale.
        M  MULTILINE   "^" matches the beginning of lines (after a newline)
                       as well as the string.
                       "$" matches the end of lines (before a newline) as well
                       as the end of the string."""
comp = r.compile("string",flags = r.IGNORECASE)
comp
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# /tmp/ipython-input-1450463359.py:1: SyntaxWarning: invalid escape sequence '\w'
#   data2 = """A  ASCII       For string patterns, make \w, \W, \b, \B, \d, \D
# re.compile(r'string', re.IGNORECASE|re.UNICODE)

# %%
comp.findall(data)
# Out:
# ['String', 'strinG', 'string', 'strIng', 'string', 'string', 'string']

# %%
comp.findall(data2)
# Out:
# ['string', 'string', 'string']

# %%
data3 = """ Each function other than purge and escape can take an optional 'flags' argument
    consisting of one or more of the following module constants, joined by "|".
    A, L, and U are mutually exclusive.
        A  ASCII       For string patterns, make \w, \W, \b, \B, \d, \D
                       match the corresponding ASCII character categories
                       (rather than the whole Unicode categories, which is the
                       default).
                       For bytes patterns, this flag is the only available
                       behaviour and needn't be specified.
        I  IGNORECASE  Perform case-insensitive matching.
        L  LOCALE      Make \w, \W, \b, \B, dependent on the current locale.
        M  MULTILINE   "^" matches the beginning of lines (after a newline)
                       as well as the string.
                       "$" matches the end of lines (before a newline) as well
                       as the end of the string."""
r.escape(data3)
# Out:
# '\\ Each\\ function\\ other\\ than\\ purge\\ and\\ escape\\ can\\ take\\ an\\ optional\\ \'flags\'\\ argument\\\n\\ \\ \\ \\ consisting\\ of\\ one\\ or\\ more\\ of\\ the\\ following\\ module\\ constants,\\ joined\\ by\\ "\\|"\\.\\\n\\ \\ \\ \\ A,\\ L,\\ and\\ U\\ are\\ mutually\\ exclusive\\.\\\n\\ \\ \\ \\ \\ \\ \\ \\ A\\ \\ ASCII\\ \\ \\ \\ \\ \\ \\ For\\ string\\ patterns,\\ make\\ \\\\w,\\ \\\\W,\\ \x08,\\ \\\\B,\\ \\\\d,\\ \\\\D\\\n\\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ match\\ the\\ corresponding\\ ASCII\\ character\\ categories\\\n\\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\(rather\\ than\\ the\\ whole\\ Unicode\\ categories,\\ which\\ is\\ the\\\n\\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ default\\)\\.\\\n\\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ For\\ bytes\\ patterns,\\ this\\ flag\\ is\\ the\\ only\\ available\\\n\\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \\ \
# ...

# %%
r.purge()

# %%
text = """Name: Rahul Kumar
Phone: 9876543210
Email: rahul.kumar@gmail.com
Alt Phone: 12345"""
text
# Out:
# 'Name: Rahul Kumar\nPhone: 9876543210\nEmail: rahul.kumar@gmail.com\nAlt Phone: 12345'

# %%
import re as r
r.findall(r"\d{10}|(\w+.\w+)@\w+.\w+",text)
# Out:
# ['', 'rahul.kumar']

# %%
text1 = "User#Name: Rahul@123!!"

r.sub(r"[^a-zA-Z0-9 ]","",text1)
# Out:
# 'UserName Rahul123'

# %%
text = """
Note 1 - Summary of Significant Accounting Policies
Unaudited Interim Financial Statements
The consolidated financial statements of Tesla, Inc. (“Tesla”, the “Company”, “we”, “us” or “our”), including the consolidated balance sheet as of
June 30, 2023, the consolidated statements of operations, the consolidated statements of comprehensive income, the consolidated statements of
redeemable noncontrolling interests and equity for the three and six months ended June 30, 2023 and 2022, and the consolidated statements of cash
flows for the six months ended June 30, 2023 and 2022, as well as other information disclosed in the accompanying notes, are unaudited. The
consolidated balance sheet as of December 31, 2022 was derived from the audited consolidated financial statements as of that date. The interim
consolidated financial statements and the accompanying notes should be read in conjunction with the annual consolidated financial statements and the
accompanying notes contained in our Annual Report on Form 10-K for the year ended December 31, 2022.
The interim consolidated financial statements and the accompanying notes have been prepared on the same basis as the annual consolidated
financial statements and, in the opinion of management, reflect all adjustments, which include only normal recurring adjustments, necessary for a fair
statement of the results of operations for the periods presented. The consolidated results of operations for any interim period are not necessarily
indicative of the results to be expected for the full year or for any other future years or interim periods.
Reclassifications
Certain prior period balances have been reclassified to conform to the current period presentation in the accompanying notes.
Revenue Recognition
Revenue by source
The following table disaggregates our revenue by major source (in millions)
Note 2 - Fair Value of Financial Instruments
ASC 820, Fair Value Measurements (“ASC 820”) states that fair value is an exit price, representing the amount that would be received to sell an
asset or paid to transfer a liability in an orderly transaction between market participants. As such, fair value is a market-based measurement that should
be determined based on assumptions that market participants would use in pricing an asset or a liability. The three-tiered fair value hierarchy, which
prioritizes which inputs should be used in measuring fair value, is comprised of: (Level I) observable inputs such as quoted prices in active markets;
(Level II) inputs other than quoted prices in active markets that are observable either directly or indirectly and (Level III) unobservable inputs for which
there is little or no market data. The fair value hierarchy requires the use of observable market data when available in determining fair value. Our
assets and liabilities that were measured at fair value on a recurring basis were as follows (in millions):
"""

# %% [markdown]
# Note 1 - Summary of Significant Accounting Policies
#
# Note 2 - Fair Value of Financial Instruments
#
# find this two data from the above text

# %%
text = '''
Follow our leader Elon musk on twitter here: https://twitter.com/elonmusk, more information
on Tesla's products can be found at https://www.tesla.com/. Also here are leading influencers
for tesla related news,
https://twitter.com/Teslarati
https://twitter.com/dummy_tesla
https://twitter.com/dummy_2_tesla
'''

# %%
text = '''
Concentration of Risk: Credit Risk
Financial instruments that potentially subject us to a concentration of credit risk consist of cash, cash equivalents, marketable securities,
restricted cash, accounts receivable, convertible note hedges, and interest rate swaps. Our cash balances are primarily invested in money market funds
or on deposit at high credit quality financial institutions in the U.S. These deposits are typically in excess of insured limits. As of September 30, 2021
and December 31, 2020, no entity represented 10% or more of our total accounts receivable balance. The risk of concentration for our convertible note
hedges and interest rate swaps is mitigated by transacting with several highly-rated multinational banks.
Concentration of Risk: Supply Risk
We are dependent on our suppliers, including single source suppliers, and the inability of these suppliers to deliver necessary components of our
products in a timely manner at prices, quality levels and volumes acceptable to us, or our inability to efficiently manage these components from these
suppliers, could have a material adverse effect on our business, prospects, financial condition and operating results.
'''

# %% [markdown]
# Concentration of Risk: Supply Risk
#
# Concentration of Risk: Credit Risk

# %% [markdown]
# ### EXERCISE
# 1. Print a string that has ‘b’ followed by zero or one ‘a’.
#
# 2. Find sequences of uppercase letter followed by underscore.
#
# 3. Find sequences of uppercase letter followed by lowercase letters.
#
# 4. Extract the words that matches a word containing ‘s’.
#
# 5. Extract the words that start with a number or a underscore.
#
# 6. Extract the words that end with a number.
#
# 7. Extract all the substring from the given string.
#
# 8. Print the occurrences and the position of the substring within the string.
#
# 9. Replace all occurrences of space with a comma.
#
# 10. Extract all five-character words from the given string.

# %% [markdown]
# https://regex101.com/

# %%
email_text = """
Hello Team,

My name is Rahul Sharma.
You can contact me at rahul.sharma123@gmail.com.
My order ID is PY01CM2862235367RC
Please resolve my issue asap.

Thanks,
Rahul
"""
# order-id and mail id

# %%
log_data = """
Error on 2025-08-20
Warning on 20/08/2025
Meeting scheduled for Aug 20, 2025
"""


# date--?

# %% [markdown]
# Validate Strong Passwords
#
# Rule:
#
# At least 8 characters
#
# One uppercase, one lowercase, one digit, one special character
#
# passwords = ["Pass123!", "weakpass", "MyStrong@2025"]
#
# match for if statement

# %%
pas = input("enter the pass")
print(pas)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3943015468.py in <cell line: 0>()
# ----> 1 pas = input("enter the pass")
#       2 print(pas)
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
# ...
